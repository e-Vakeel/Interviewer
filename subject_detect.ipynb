# %%
import google.generativeai as genai

# %%
genai.configure(api_key='')

# %%
models = genai.list_models()
for model_name in models:
  print(model_name.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-8b-exp-0827
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
model = genai.GenerativeModel('gemini-1.5-flash-8b-exp-0827')

# %%
cn_questions = [
  '''What is the purpose of the OSI model in networking?
— A. To define the architecture for network protocols
— B. To establish a framework for software development
— C. To specify the physical network infrastructure
— D. To manage network security
''' ,

'''Which layer of the OSI model is responsible for end-to-end communication and provides services like encryption and decryption?
— A. Transport Layer
— B. Presentation Layer
— C. Application Layer
— D. Session Layer
''' ,

'''What is the primary function of the Network Layer in the OSI model?
— A. Error detection and correction
— B. Data link control
— C. Routing and addressing
— D. Session establishment and termination
''' ,

'''Which addressing scheme is used by IPv6?
— A. 32-bit
— B. 128-bit
— C. 64-bit
— D. 16-bit
''' ,

'''What is the purpose of ARP (Address Resolution Protocol)?
— A. To map IP addresses to MAC addresses
— B. To discover the default gateway
— C. To resolve domain names to IP addresses
— D. To establish a secure connection
''' ,

'''In networking, what is the function of a router?
— A. Connects devices within the same network
— B. Filters and forwards packets between different networks
— C. Manages network security
— D. Assigns IP addresses dynamically
''' ,

'''Which protocol is used for secure communication over a computer network?
— A. HTTP
— B. FTP
— C. SSH
— D. SNMP
''' ,

'''What is the primary purpose of DNS (Domain Name System)?
— A. Assigning IP addresses to devices
— B. Resolving domain names to IP addresses
— C. Encrypting network communication
— D. Managing network resources
''' ,

'''Which subnet mask is associated with the Class B IP address range?
— A. 255.255.255.0
— B. 255.0.0.0
— C. 255.255.0.0
— D. 255.255.255.255
''' ,

'''What is the purpose of ICMP (Internet Control Message Protocol)?
— A. To encapsulate data for transmission
— B. To manage network traffic congestion
— C. To diagnose network-related issues
— D. To establish a secure connection
''' ,

'''What does NAT (Network Address Translation) do in networking?
— A. Assigns unique IP addresses to devices
— B. Maps private IP addresses to a public IP address
— C. Encrypts network traffic
— D. Manages network security policies
''' ,

'''Which of the following is a layer-2 device in a network?
— A. Router
— B. Switch
— C. Hub
— D. Firewall
''' ,

'''What is the role of a firewall in computer networks?
— A. Managing IP addresses
— B. Filtering and controlling network traffic
— C. Resolving domain names to IP addresses
— D. Assigning MAC addresses dynamically
''' ,

'''Which protocol is used for file transfer over a network?
— A. HTTP
— B. FTP
— C. SMTP
— D. POP3
''' ,

'''What is the purpose of DHCP (Dynamic Host Configuration Protocol)?
— A. To encrypt network communication
— B. To assign IP addresses dynamically to devices
— C. To manage network security
— D. To establish a secure tunnel
''' ,

'''What does the term “bandwidth” refer to in networking?
— A. The speed of data transmission
— B. The distance between devices in a network
— C. The number of devices in a network
— D. The size of network packets
''' ,

'''Which of the following is a topological design where each device is connected to every other device in the network?
— A. Bus topology
— B. Star topology
— C. Ring topology
— D. Mesh topology
''' ,

'''What is the purpose of a proxy server in networking?
— A. To manage IP addresses
— B. To filter and forward network traffic
— C. To assign MAC addresses dynamically
— D. To encrypt network communication
''' ,

'''Which TCP/IP protocol is responsible for ensuring the reliable delivery of data packets?
— A. IP
— B. UDP
— C. TCP
— D. ICMP
''' ,

'''What is the function of a DNS resolver in the DNS hierarchy?
— A. Translating domain names to IP addresses
— B. Managing top-level domain servers
— C. Resolving IP addresses to domain names
— D. Authenticating domain registrations
''' ,

'''What is the purpose of the HTTP protocol in networking?
— A. File transfer
— B. Email communication
— C. Web page retrieval
— D. Remote login
''' ,

'''In networking, what does the term “ping” refer to?
— A. Testing network connectivity
— B. Filtering network traffic
— C. Assigning IP addresses
— D. Managing network security
''' ,

'''Which of the following is a valid IPv4 address?
— A. 192.256.1.1
— B. 172.31.0.1
— C. 300.100.50.25
— D. 500.10.5.2
''' ,

'''What is the purpose of the HTTPS protocol in networking?
— A. File transfer
— B. Secure web page retrieval
— C. Email communication
— D. Remote login
''' ,

'''Which network device operates at the Data Link Layer (Layer 2) of the OSI model?
— A. Router
— B. Hub
— C. Switch
— D. Firewall
''' ,

'''What does the term “subnetting” refer to in networking?
— A. Dividing a large network into smaller, logical networks
— B. Allocating IP addresses to devices
— C. Filtering network traffic
— D. Assigning MAC addresses
''' ,

'''Which protocol is used for sending and receiving emails?
— A. HTTP
— B. FTP
— C. SMTP
— D. SNMP
''' ,

'''What is the purpose of the UDP (User Datagram Protocol) in networking?
— A. Reliable data transmission
— B. Connection-oriented communication
— C. Error detection and correction
— D. Fast and efficient data transmission
''' ,

'''Which of the following is a private IP address?
— A. 192.168.1.1
— B. 172.16.0.1
— C. 10.0.0.1
— D. All of the above
''' ,

'''What is the purpose of the BGP (Border Gateway Protocol) in networking?
— A. Dynamic routing between autonomous systems
— B. Reliable data transmission
— C. Filtering network traffic
— D. Assigning IP addresses dynamically
''' ,
]

# %%
os_questions = ['''
Q1. What is the most used computer operating system?

Linux
Windows
Chrome os
Android
''' , '''

Q2. What was the first operating system?

Linux
Windows
GM NAA I/O
Android
''' , '''

Q3. When was the first operating system built?

1956
1950
1952
1960
''' , '''

Q4. What is the first windows version?

Windows NT
Windows 3.0
Windows 1.01
Windows XP
''' , '''

Q5. What does an operating system do?

An interface that regulates hardware and software programs
A hardware device
A program that operates the hardware devices
All of the above
''' , '''

Q6. What type of extension name do notepads use?

.png
.txt
.jpeg
.xip
''' , '''

Q7. What is the full form of BIOS?

Between input-output system
Binary input-output system
Basic input/output system
All of the above
''' , '''

Q8. What does FAT mean?

File format attribute
Font allocation tree
File allocation table
Font attribute table
''' , '''

Q9. Who needs a BIOS to function properly?

A mobile device
An operating system
Hardware devices
All of the above
''' , '''

Q10. What does restarting an operating system do?

Restarts all the processes
Shuts down the operating system completely
Terminates all running programs completely
All of the above
''' , '''

Q11. What operations mentioned are done by an operating system?

Maintaining recycle bin
Transfer files
Opens a program
All of the above
''' , '''

Q12. Where are the errors and bugs recorded?

notepad
New program
Running process
Logfile
''' , '''

Q13. Which one of the following isn’t considered a real-time operating system?

PSOS
linuxRT
VRTX
Windows
''' , '''

Q14. What are the properties of processes in an operating system?

Global variables, personal address
Shutdown
Restarting services
All of the above
''' , '''

Q15. What are file extensions?

Log files
Output types for file formats
Software programs
All of the above
''' , '''

Q16. What is a batch operating system?

Multiple individual tasks
Similar types of tasks are grouped together
Tasks operating at different systems
All of the above
''' , '''

Q17. What is a time sharing operating system?

Makes use of log files to do basic task
One shell seems to be shared
Allows users to use one system with two different terminals
All of the above
''' , '''

Q18. What of the following isn’t directly related to the operating system?

BIOS
Software programs
Hardware devices
All of the above
''' , '''

Q19. What makes an operating system whole?

Log files
Input devices
Output devices
All of the above
''' , '''

Q20. What is FIFO scheduling?

First input-output scheduling
First in first out scheduling
Free input free output
All of the above
''' ,
]

# %%
dbms_questions = [ '''
  1. ____________ offers the ability to query the data and insert, alter, and delete tuples.

a. Transaction Control Language (TCL)

b. Data Control Language (DCL)

c. Data Definition Language (DDL)

d. Data Manipulation Language (DML)

''' , '''

2. We can add or remove the user IDs using which of these fixed roles?

a. db_setupadmin

b. db_securityadmin

c. db_accessadmin

d. db_sysadmin

''' , '''

3. Section (sect name, wing, expenses) and Student (student_ID, name, sect name, fees).

Here in both of these relations, the sect_name attribute appears commonly. In this case, using common attributes in the relation schema is a way in which we can relate the ___________ relations.

a. Tuple of common

b. Attributes of common

c. Attributes of distinct

d. Tuple of distinct

''' , '''

4.

SELECT title

FROM teacher

WHERE fees <= 200000 AND fees >= 80000;

We can replace this query by which of these?

a.

SELECT title

FROM teacher

WHERE fees BETWEEN 200000 AND 80000;

b.

SELECT title

FROM staff

WHERE fees BETWEEN 80000 AND 200000;

c.

SELECT title

FROM staff

WHERE fees <= 80000 AND fees >=200000;

d.

SELECT title

FROM teacher

WHERE fees BETWEEN 80000 AND 200000;

''' , '''

SELECT title

FROM teacher

WHERE fees BETWEEN 80000 AND 200000;

5. Which symbol do we use in place of the except?

a. ~

b. ¬

c. V

d. ^

''' , '''

6. What is an alternative name for a weak entity?

a. Dominant

b. Owner

c. Child

d. All of the above

''' , '''

7. Assume a relation X (M, N, O, P, Q) that has the following functional dependencies:

MNO -> PQ and

P -> MN

The total number of superkeys of X would be:

a. 12

b. 10

c. 7

d. 2

''' , '''

8. Fifth Normal form is concerned with:

a. Join dependency

b. Domain-key

c. Multivalued dependency

d. Functional dependency

''' , '''

9. The _____ system does not require a password to travel across the internet.

a. Response

b. Challenge-response

c. Manipulation

d. Readable

''' , '''

10. We can force a log switch by using:

a. ALTER SYS LOGFILES

b. ALTER SYSTEM SWITCH LOGS

c. ALTER SYSTEM LOG

d. ALTER SYSTEM SWITCH LOGFILE

''' , '''

11. When recovering from a failure:

a. examination of each pair of physical blocks occurs

b. examination of a specified pair of physical blocks occurs

c. examination of the first pair of physical blocks occurs

d. none of the above

''' , '''

12. The Optical disk technology utilises:

a. RAID

b. A laser beam

c. DAT

d. Helical scanning

''' , '''

13. The node pointing towards another node in a B+ tree is known as:

a. External node

b. Leaf node

c. Internal node

d. Final node

''' , '''

14. Identify the statement among the following that is FALSE:

a. The relation in which all keys have only a single attribute is in its 2NF

b. A relation that has two attributes is in its BCNF

c. The prime attribute can depend transitively on any key in the case of a relation that is in its BCNF

d. The prime attribute can depend transitively on any key in the case of a relation that is in its 3 NF

''' , '''

15. A transaction enters into its _______ state when it finishes the final statement.

a. Abort state

b. Partially committed state

c. Committed state

d. Active state

''' , '''

16. An operator shall provide the transaction file’s name, and the file consisting of the edited transactions (that are ready for execution) must be called:

a. Trans. Exe

b. Batch. Exe

c. Edit. Exe

d. Opt. Exe

''' , '''

17. In crabbing, the protocol locking goes:

a. down the tree, back up

b. up the tree, back down

c. down the tree, releases

d. up the tree, releases

''' , '''

18. The name of the very first microprocessor chip available commercially was:

a. Intel 4004

b. Intel 639

c. Intel 308

d. Motorola 33

''' , '''

19. The easiest way in which we can transfer control is when the old backup site sends __________ to the old primary.

a. Redo logs

b. Primary Logs

c. Undo Logs

d. All of the above

''' , '''

20. A linear search algorithm’s complexity would be:

a. O(n2)

b. O(n log n)

c. O(n)

d. O(log n)

''' ,
]

# %%
oops_questions = [ '''
  1. Which of these features of OOP would indicate code reusability?

a. Polymorphism

b. Abstraction

c. Inheritance

d. Encapsulation

''' , '''

2. Which language does not support polymorphism but supports classes?

a. Ada

b. C++

c. Java

d. SmallTalk

''' , '''

3. Which of these specifiers would be applied to the constructors only?

a. Explicit

b. Implicit

c. Protected

d. Public

''' , '''

4. A constructor _____________.

a. May consist of a return type

b. Doesn’t consist of any return type

c. Has some return type

d. Of a derived class has a return type

''' , '''

5. The access specifier that is/are the most secure during inheritance is/are _______________.

a. Protected

b. Private

c. Private and Default

d. Default

''' , '''

6. If in case, in multiple inheritances, a class R would inherit the Class Q, while Class Q would inherit the class P, then in which sequence would their destructors be called in case we declare an object of Class R?

a. ~R() then ~P() then ~Q()

b. ~P() then ~Q() then ~R()

c. ~Q() then ~R() then ~P()

d. ~R() then ~Q() then ~P()

''' , '''

7. The memory that is allocated for any objects is ____________.

a. Cache

b. HDD

c. ROM

d. RAM

''' , '''

8. Which of these classes is a specialization of some more general template classes?

a. Integer

b. Maths

c. String

d. Digit

''' , '''

9. A derived class is also called a ______________.

a. Small class

b. Subclass

c. Noticeable class

d. Big class

''' , '''

10. Which of these inheritances is shown in case we inherit some base class from another class, then one of the classes derives it?

a. Single

b. Multiple

c. Multi-level

d. Hierarchical

''' , '''

11. Hierarchical inheritance could be some subset of _________________ inheritance.

a. Multilevel

b. Single level

c. Multiple

d. Hybrid

''' , '''

12. What is the name of the feature in which we enforce the definitions of the abstract function at the compile time?

a. Dynamic Polymorphism

b. Static Polymorphism

c. Dynamic or Static Polymorphism according to need

d. Polymorphism

''' , '''

13. If in case a class is called in the main function directly and has a public member function, then ____________________.

a. It will lead to the production of an undeclared function error

b. It will lead to the production of an out of memory error

c. The program will only give warning

d. The program will shut the computer down

''' , '''

14. __________ is the universal handler class for exceptions.

a. Maths

b. Object

c. Exceptions

d. Errors

''' , '''

15. For catching multiple exceptions in a single catch block, then how do we separate exceptions in the syntax?

a. Hyphen

b. Vertical bar

c. Modulus

d. Plus

''' , '''

16. Where are the temporary objects (that are created during the return by value) created?

a. Inside the calling function

b. Inside the main function

c. Within the function

d. Outside the function scope

Answer:(c) Within the function

17. What shall we use in the case of safe downcast?

a. Implicit cast

b. Manual cast

c. Dynamic cast

d. Static cast

''' , '''

18. Which of these types of values result from a delete operator?

a. null

b. null pointer

c. void pointer

d. void

''' , '''

19. Which of these attributes can we use if we want to get the actual size of any array?

a. Array_name.length

b. Size.Array

c. length.Array_name

d. Array.Size

''' , '''

20. Which function is used to get any character that is present at a certain index of a string?

a. char charIn(StringName);

b. char charAt(index);

c. char charIn(index);

d. char charAt(StringName);

''' ,
]

# %%
from IPython.display import Markdown

import textwrap

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
counter = 0
for question in dbms_questions:
  prompt = f''' will give you a question. You have to categorize the question ONLY into four categories depending on the subject of the questions. The categories are:
  Computer Networks,
  Operating System,
  Database Management System,
  Object Oriented Programming
  The questions is:
  {question}
  Answer as short as possible. Don't use markdown'''
  response = model.generate_content(prompt)
  print(response.text)
  counter += 1
  if counter > 2:
    break

print(counter)
# Out:
# Database Management System
# Database Management System
# Database Management System
# 3

# %%
prompt = f'''I will give you a question. You have to categorize the question ONLY into four categories depending on the subject of the questions. The categories are:
  Computer Networks,
  Operating System,
  Database Management System,
  Object Oriented Programming
  The questions is:
  Who wrote the book poor economics?
  Answer as short as possible. Don't use markdown. If the question is from any other category, answer \'None\''''
response = model.generate_content(prompt)
print(response.text)

# %%
question = ""
prompt = f'''I will give you a question. You have to categorize the question ONLY into the following categories depending on the subject of the questions. The categories are:
  Computer Networks,
  Operating System,
  Database Management System,
  Object Oriented Programming,
  Aptitude Based.
Further, if the question is aptitude based, classify it into the following categories:
Quantitative,
Verbal ability and Reading Comprehension,
Data Interpretation and Logical Reasoning

For example:
Question. Where are the temporary objects (that are created during the return by value) created?
Reply. Object Oriented Programming

Question. What is an alternative name for a weak entity?
Reply. Database Management System

Question. What does an operating system do?
Reply. Operating System

Question. What is the purpose of ICMP (Internet Control Message Protocol)?
Reply. Computer Networks

Question. Two pipes A and B can fill a tank separately in 12 and 16 hours respectively. If both of them are opened together when the tank is initially empty, how much time will it take to completely fill the tank? 
Reply. Quantitative

Question. In recent years, the concept of "digital detox" has gained popularity as individuals seek to reduce their reliance on electronic devices. While technology has undoubtedly brought many benefits, such as improved communication and access to information, there is growing concern about its negative impact on mental health. Proponents of digital detox argue that excessive screen time can lead to increased stress, reduced productivity, and diminished personal relationships. They advocate for regular breaks from digital devices to restore balance and improve overall well-being. Critics, however, suggest that the emphasis on digital detox may be an overreaction and that technology itself is not inherently harmful. Instead, they argue that it is the way individuals use technology that matters. Which of the following statements best captures the main argument of the passage?
Reply. Verbal Ability and Reading Comprehension

Question. A company tracks the time employees spend on various types of tasks during a typical workday. Over the past month, the company has observed the following distribution of hours spent on different activities by an average employee:
Client Meetings: 35% of the workday
Project Work: 45% of the workday
Administrative Tasks: 15% of the workday
Training and Development: 5% of the workday
If an employee works for 8 hours a day, how many hours does the employee spend on Project Work each day?
Reply. Data Interpretation and Logical Reasoning

  The questions is:
  {question}
  Answer as short as possible. Don't use markdown. If the question is from any other category, answer \'None\''''
response = model.generate_content(prompt)
print(response.text)
